# %%
import pandas as pd

# %%
df = pd.read_csv("fortune_data.csv")

# %%
df.columns
# Out:
# Index(['Rank', 'Company', 'Sector', 'Industry', 'Location', 'Revenue',
#        'Profits', 'Employees'],
#       dtype='object')

# %%
df["Sector"].unique()
# Out:
# array(['Retailing', 'Energy', 'Technology', 'Financials', 'Health Care',
#        'Food and Drug Stores', 'Motor Vehicles & Parts',
#        'Telecommunications', 'Industrials', 'Aerospace & Defense',
#        'Household Products', 'Food, Beverages & Tobacco',
#        'Transportation', 'Media', 'Chemicals', 'Wholesalers', 'Apparel',
#        'Hotels, Resturants & Leisure', 'Materials', 'Business Services',
#        'Engineering & Construction'], dtype=object)

# %%
df["Sector"].nunique()
# Out:
# 21

# %%
df_energy= df [ df["Sector"]=="Energy" ]

# %%
df_energy.value_counts("Sector")
# Out:
# Sector
# Energy    122
# Name: count, dtype: int64

# %%
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
df = pd.read_csv("fortune_data.csv")

sectorData_df = df.groupby(by=["Sector"])

# %%
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
len(sectorData_df)
# Out:
# 21

# %%
sectorData_df.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
sectorData_df.first()
# Out:
#                               Rank                 Company  \
# Sector
# Aerospace & Defense             24                  Boeing
# Apparel                         91                    Nike
# Business Services              144           ManpowerGroup
# Chemicals                       56            Dow Chemical
# Energy                           2             Exxon Mobil
# Engineering & Construction     155                   Fluor
# Financials                       4      Berkshire Hathaway
# Food and Drug Stores             7              CVS Health
# Food, Beverages & Tobacco       41  Archer Daniels Midland
# Health Care                      5                McKesson
# Hotels, Resturants & Leisure   109              McDonald’s
# Household Products              34        Procter & Gamble
# Industrials                     11        General Electric
# Materials                      126                   Alcoa
# Media                           53                  Disney
# ...

# %%
sectorData_df.get_group("Technology")
# Out:
#      Rank                Company      Sector  \
# 2       3                  Apple  Technology
# 17     18             Amazon.com  Technology
# 19     20                     HP  Technology
# 24     25              Microsoft  Technology
# 30     31                    IBM  Technology
# ..    ...                    ...         ...
# 969   970      Rackspace Hosting  Technology
# 970   971       VeriFone Systems  Technology
# 974   975   Super Micro Computer  Technology
# 983   984  Nuance Communications  Technology
# 989   990            F5 Networks  Technology
#
#                                        Industry         Location  Revenue  \
# 2                   Computers, Office Equipment    Cupertino, CA   233715
# 17              Internet Services and Retailing      Seattle, WA   107006
# 19                  Computers, Office Equipment    Palo Alto, CA   103355
# 24                            Computer Software      Redmond, WA    93580
# ...

# %%
sectorData_df.max()
# Out:
#                               Rank                 Company  \
# Sector
# Aerospace & Defense            987                Woodward
# Apparel                        917    Wolverine World Wide
# Business Services              993           Western Union
# Chemicals                      949       Westlake Chemical
# Energy                         997             Xcel Energy
# Engineering & Construction     994            Tutor Perini
# Financials                     996          Zions Bancorp.
# Food and Drug Stores           928      Whole Foods Market
# Food, Beverages & Tobacco      954         WhiteWave Foods
# Health Care                    978         inVentiv Health
# Hotels, Resturants & Leisure   999              Yum Brands
# Household Products             992           Vista Outdoor
# Industrials                   1000      Zebra Technologies
# Materials                      986  Worthington Industries
# Media                          989             iHeartMedia
# ...

# %%
sectorData_df["Revenue"].max()
# Out:
# Sector
# Aerospace & Defense              96114
# Apparel                          30601
# Business Services                19330
# Chemicals                        48778
# Energy                          246204
# Engineering & Construction       18114
# Financials                      210821
# Food and Drug Stores            153290
# Food, Beverages & Tobacco        67702
# Health Care                     181241
# Hotels, Resturants & Leisure     25413
# Household Products               78756
# Industrials                     140389
# Materials                        22534
# Media                            52465
# Motor Vehicles & Parts          152356
# Retailing                       482130
# Technology                      233715
# Telecommunications              146801
# Transportation                   58363
# Wholesalers                      48681
# Name: Revenue, dtype: int64

# %%
sectorData_df["Profits"].min()
# Out:
# Sector
# Aerospace & Defense              -240
# Apparel                            82
# Business Services               -1481
# Chemicals                        -816
# Energy                         -23119
# Engineering & Construction       -155
# Financials                      -1194
# Food and Drug Stores              -62
# Food, Beverages & Tobacco        -253
# Health Care                      -458
# Hotels, Resturants & Leisure    -1394
# Household Products              -1149
# Industrials                     -6126
# Materials                       -1642
# Media                            -881
# Motor Vehicles & Parts           -889
# Retailing                       -1243
# Technology                      -4359
# Telecommunications               -271
# Transportation                   -191
# Wholesalers                      -502
# Name: Profits, dtype: int64

# %%
sectorData_df.agg({"Profits":["min","max"],
                  "Revenue":["max","mean"],
                  "Employees":"mean"})
# Out:
#                              Profits        Revenue                \
#                                  min    max     max          mean
# Sector
# Aerospace & Defense             -240   7608   96114  17897.000000
# Apparel                           82   3273   30601   6397.866667
# Business Services              -1481   6328   19330   5337.156863
# Chemicals                       -816   7685   48778   8129.900000
# Energy                        -23119  16150  246204  12441.057377
# Engineering & Construction      -155    803   18114   5922.423077
# Financials                     -1194  24442  210821  15950.784173
# Food and Drug Stores             -62   5237  153290  32251.266667
# Food, Beverages & Tobacco       -253   7351   67702  12929.465116
# Health Care                     -458  18108  181241  21529.426667
# Hotels, Resturants & Leisure   -1394   5920   25413   6781.840000
# Household Products             -1149   7036   78756   8383.464286
# ...

# %%
sectorData_df.agg( ["size","sum","max"])
# Out:
#                              Rank              Company  \
#                              size    sum   max    size
# Sector
# Aerospace & Defense            20   8870   987      20
# Apparel                        15   8757   917      15
# Business Services              51  31074   993      51
# Chemicals                      30  15928   949      30
# Energy                        122  62199   997     122
# Engineering & Construction     26  15147   994      26
# Financials                    139  63566   996     139
# Food and Drug Stores           15   6429   928      15
# Food, Beverages & Tobacco      43  18629   954      43
# Health Care                    75  31770   978      75
# Hotels, Resturants & Leisure   25  14039   999      25
# Household Products             28  15749   992      28
# Industrials                    46  26988  1000      46
# Materials                      43  23343   986      43
# Media                          25  13976   989      25
# ...

# %%
sectorData_df.agg( ["min","max"])
# Out:
#                              Rank                              Company  \
#                               min   max                            min
# Sector
# Aerospace & Defense            24   987                  B/E Aerospace
# Apparel                        91   917                       Carter’s
# Business Services             144   993                 ABM Industries
# Chemicals                      56   949                    A. Schulman
# Energy                          2   997                            AES
# Engineering & Construction    155   994                          AECOM
# Financials                      4   996                            AIG
# Food and Drug Stores            7   928                     CVS Health
# Food, Beverages & Tobacco      41   954     Alliance One International
# Health Care                     5   978                         AbbVie
# Hotels, Resturants & Leisure  109   999                Bloomin’ Brands
# ...

# %%
df_data= sectorData_df.agg({"Profits":"min",
                  "Revenue":"max",
                  "Employees":"mean"})

# %%
type(df_data)
# Out:
# pandas.core.frame.DataFrame

# %%
df_data["Employees"]=df_data["Employees"].round(2)

# %%
df_data
# Out:
#                               Profits  Revenue  Employees
# Sector
# Aerospace & Defense              -240    96114   48402.85
# Apparel                            82    30601   23093.13
# Business Services               -1481    19330   26687.25
# Chemicals                        -816    48778   15455.03
# Energy                         -23119   246204    9745.30
# Engineering & Construction       -155    18114   15642.62
# Financials                      -1194   210821   24172.29
# Food and Drug Stores              -62   153290   93026.53
# Food, Beverages & Tobacco        -253    67702   28177.49
# Health Care                      -458   181241   35710.52
# Hotels, Resturants & Leisure    -1394    25413   99369.80
# Household Products              -1149    78756   23072.79
# Industrials                     -6126   140389   33591.93
# Materials                       -1642    22534   14840.07
# Media                            -881    52465   22012.56
# ...

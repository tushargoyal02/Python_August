# %%
#  function: block of code => logic

def hello():
    print("hey user tushar")

# %%
hello()
hello()
# Out:
# hey user tushar
# hey user tushar

# %%
# a, b => parameter ( variable)
def hello(a,b):
    print(a+b)
    print("hey user tushar")

# %%
hello(10,20)
hello(5,67)
# Out:
# 30
# hey user tushar
# 72
# hey user tushar

# %%
def hello(a,b):
    print("Value of a is ",a)
    print("Value of b is ",b)
    
# type value pass - required argument
hello(10,20)
# Out:
# Value of a is  10
# Value of b is  20

# %%
def hello(a,b):
    print("Value of a is ",a)
    print("Value of b is ",b)
    
# type value pass - required argument
hello(20,10)
# Out:
# Value of a is  20
# Value of b is  10

# %%
def hello(a,b):
    print("Value of a is ",a)
    print("Value of b is ",b)
    
# type value pass - required argument
hello(20,10)
# Out:
# Value of a is  20
# Value of b is  10

# %%
def facebook(id, uname, email):
    print("id:",id, "uname:",uname,"email:",email)

# %%
facebook(1,"tushar")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 facebook(1,"tushar")
#
# TypeError: facebook() missing 1 required positional argument: 'email'

# %%
# data pass function => variable length argument
def facebook( *data):
    print(data, type(data))

facebook(1,2,"hey")
# Out:
# (1, 2, 'hey') <class 'tuple'>

# %%
# keyword variable length argumentg

#  *args and kwargs 

def facebook( **data):
    print(data, type(data))

facebook(id=1,age=2,msg="hey")
# Out:
# {'id': 1, 'age': 2, 'msg': 'hey'} <class 'dict'>

# %%
import pandas as pd

# %%
df= pd.read_csv("C:/Users/admin/Desktop/DataScience/Python/NbaInfo.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(4)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0

# %%
df.tail(4)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df[["Team","Salary"]]
# Out:
#                Team     Salary
# 0    Boston Celtics  7730337.0
# 1    Boston Celtics  6796117.0
# 2    Boston Celtics        NaN
# 3    Boston Celtics  1148640.0
# 4    Boston Celtics  5000000.0
# ..              ...        ...
# 453       Utah Jazz  2433333.0
# 454       Utah Jazz   900000.0
# 455       Utah Jazz  2900000.0
# 456       Utah Jazz   947276.0
# 457             NaN        NaN
#
# [458 rows x 2 columns]

# %%
df.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
df.dropna()
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df.dropna(how="all").tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
#
#         Salary
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
df.dropna(subset=["Salary","College"],inplace=True)

# %%
df["newsalary"]=df["Salary"]/10

# %%
df["newValue"]=50
df.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary  newsalary  newValue
# 0      Texas  7730337.0   773033.7        50
# 1  Marquette  6796117.0   679611.7        50

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary', 'newsalary', 'newValue'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df.drop(columns=["newsalary","newValue"] , inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...

# %%
# df.drop(columns=["newsalary","newValue"] , inplace=True)
df.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
import pandas as pd
df= pd.read_csv("C:/Users/admin/Desktop/DataScience/Python/NbaInfo.csv")

# %%
df.dropna(how="all", inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 35.7+ KB

# %%
df["Salary"]=df["Salary"].fillna(0)

# %%
df["Rank"]= df["Salary"].rank(ascending=False).astype(int)

# %%
df.sort_values(by="Salary", ascending=False).head(15)
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 109        Kobe Bryant     Los Angeles Lakers    24.0       SF  37.0    6-6
# 169       LeBron James    Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33     Carmelo Anthony        New York Knicks     7.0       SF  32.0    6-8
# 251      Dwight Howard        Houston Rockets    12.0        C  30.0   6-11
# 339         Chris Bosh             Miami Heat     1.0       PF  32.0   6-11
# 100         Chris Paul   Los Angeles Clippers     3.0       PG  31.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
# 164       Derrick Rose          Chicago Bulls     1.0       PG  27.0    6-3
# 349        Dwyane Wade             Miami Heat     3.0       SG  34.0    6-4
# 174         Kevin Love    Cleveland Cavaliers     0.0       PF  27.0   6-10
# 98      DeAndre Jordan   Los Angeles Clippers     6.0        C  27.0   6-11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 457 entries, 0 to 456
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    457 non-null    float64
#  9   Rank      457 non-null    int32
# dtypes: float64(4), int32(1), object(5)
# memory usage: 37.5+ KB

# %%
df.sort_values(by="Salary").head(20)
# Out:
#                        Name                    Team  Number Position   Age  \
# 397            Axel Toupane          Denver Nuggets     6.0       SG  23.0
# 350           Briante Weber              Miami Heat    12.0       PG  23.0
# 2              John Holland          Boston Celtics    30.0       SG  27.0
# 171           Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0
# 270          Xavier Munford       Memphis Grizzlies    14.0       PG  24.0
# 269            Ray McCallum       Memphis Grizzlies     5.0       PG  24.0
# 353           Dorell Wright              Miami Heat    11.0       SF  30.0
# 409              Greg Smith  Minnesota Timberwolves     4.0       PF  25.0
# 46              Elton Brand      Philadelphia 76ers    42.0       PF  37.0
# 273          Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0
# 264           Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0
# ...

# %%
mock=df["Age"].isin( [25.0,30.0] )
df [ mock ]
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 0      Avery Bradley          Boston Celtics     0.0       PG  25.0    6-2
# 1        Jae Crowder          Boston Celtics    99.0       SF  25.0    6-6
# 7       Kelly Olynyk          Boston Celtics    41.0        C  25.0    7-0
# 26   Thomas Robinson           Brooklyn Nets    41.0       PF  25.0   6-10
# 30     Arron Afflalo         New York Knicks     4.0       SG  30.0    6-5
# ..               ...                     ...     ...      ...   ...    ...
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 421   Anthony Morrow   Oklahoma City Thunder     2.0       SG  30.0    6-5
# 428  Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0    6-9
# 436   Damian Lillard  Portland Trail Blazers     0.0       PG  25.0    6-3
# 440    Brian Roberts  Portland Trail Blazers     2.0       PG  30.0    6-1
#
#      Weight       College     Salary  Rank
# ...

# %%
df [ df["Age"].between(25.0,30.0) ]
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 450     Joe Ingles       Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College      Salary  Rank
# 0                Texas   7730337.0    97
# ...

# %%
df[ ~df["Team"].duplicated(keep="first") ]
# Out:
#                       Name                    Team  Number Position   Age  \
# 0            Avery Bradley          Boston Celtics     0.0       PG  25.0
# 15        Bojan Bogdanovic           Brooklyn Nets    44.0       SG  27.0
# 30           Arron Afflalo         New York Knicks     4.0       SG  30.0
# 46             Elton Brand      Philadelphia 76ers    42.0       PF  37.0
# 61         Bismack Biyombo         Toronto Raptors     8.0        C  23.0
# 76         Leandro Barbosa   Golden State Warriors    19.0       SG  33.0
# 91            Cole Aldrich    Los Angeles Clippers    45.0        C  27.0
# 106           Brandon Bass      Los Angeles Lakers     2.0       PF  31.0
# 121           Eric Bledsoe            Phoenix Suns     2.0       PG  26.0
# 136             Quincy Acy        Sacramento Kings    13.0       SF  25.0
# 151       Cameron Bairstow           Chicago Bulls    41.0       PF  25.0
# 166    Matthew Dellavedova     Cleveland Cavaliers     8.0       PG  25.0
# ...

# %%
df.drop_duplicates(subset="Team")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 ~df.drop_duplicates(subset="Team")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:1461, in NDFrame.__invert__(self)
#    1457 if not self.size:
#    1458     # inv fails with 0 len
#    1459     return self.copy(deep=False)
# -> 1461 new_data = self._mgr.apply(operator.invert)
#    1462 return self._constructor(new_data).__finalize__(self, method="__invert__")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:350, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     347             kwargs[k] = obj[b.mgr_locs.indexer]
#     349 if callable(f):
# --> 350     applied = b.apply(f, **kwargs)
#     351 else:
#     352     applied = getattr(b, f)(**kwargs)
#
# ...
